# %%
import numpy
from skimage.io import imread
import cv2, json, pandas as pd

# %%
image_path = '/mnt/windows/16-080L/Xenium/XE009_Prostate TMA_122623.lif_XE009_0015980_Array C.ome.tif'
output_path = '/mnt/windows/16-080L/Xenium/raw_reg_img/HE.flipped.tif'

# %%
original_image = imread(image_path)

# %%
original_image.shape
# Out:
# (47123, 30504, 3)

# %% [markdown]
# ## Flip image left right / vertically
# https://datahacker.rs/003-how-to-resize-translate-flip-and-rotate-an-image-with-opencv/

# %%
# 1 for vertical LEFT_RIGHT
# 0 for horizontal flip TOP_BOTTOM
flipped = cv2.flip(original_image, 1)

# %%
flipped.shape
# Out:
# (47123, 30504, 3)

# %%
cv2.imwrite(output_path, flipped)
# Out:
# True
